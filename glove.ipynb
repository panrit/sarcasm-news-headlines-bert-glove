# %%
# !pip install -q transformers
# Out:
#      |████████████████████████████████| 4.7 MB 7.3 MB/s
#      |████████████████████████████████| 596 kB 71.9 MB/s
#      |████████████████████████████████| 101 kB 12.9 MB/s
#      |████████████████████████████████| 6.6 MB 43.3 MB/s

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
df = pd.read_json('/gdrive/MyDrive/Colab Notebooks/Sarcasm_Headlines_Dataset_v2.json', lines=True)

# %%
df.head()
# Out:
#    is_sarcastic                                           headline  \
# 0             1  thirtysomething scientists unveil doomsday clo...
# 1             0  dem rep. totally nails why congress is falling...
# 2             0  eat your veggies: 9 deliciously different recipes
# 3             1  inclement weather prevents liar from getting t...
# 4             1  mother comes pretty close to using word 'strea...
#
#                                         article_link
# 0  https://www.theonion.com/thirtysomething-scien...
# 1  https://www.huffingtonpost.com/entry/donna-edw...
# 2  https://www.huffingtonpost.com/entry/eat-your-...
# 3  https://local.theonion.com/inclement-weather-p...
# 4  https://www.theonion.com/mother-comes-pretty-c...

# %%
df.shape
# Out:
# (28619, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28619 entries, 0 to 28618
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   is_sarcastic  28619 non-null  int64
#  1   headline      28619 non-null  object
#  2   article_link  28619 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 670.9+ KB

# %%
df.isnull().values.any()
# Out:
# False

# %%
df['is_sarcastic'].value_counts().plot(kind = 'bar', rot=0)
plt.title("Distribution")
plt.xticks(range(2), ['not sarcastic', 'sarcastic'])
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df.is_sarcastic.value_counts()
# Out:
# 0    14985
# 1    13634
# Name: is_sarcastic, dtype: int64

# %%
df.article_link
# Out:
# 0        https://www.theonion.com/thirtysomething-scien...
# 1        https://www.huffingtonpost.com/entry/donna-edw...
# 2        https://www.huffingtonpost.com/entry/eat-your-...
# 3        https://local.theonion.com/inclement-weather-p...
# 4        https://www.theonion.com/mother-comes-pretty-c...
#                                ...
# 28614    https://www.theonion.com/jews-to-celebrate-ros...
# 28615    https://local.theonion.com/internal-affairs-in...
# 28616    https://www.huffingtonpost.com/entry/andrew-ah...
# 28617    https://www.theonion.com/mars-probe-destroyed-...
# 28618    https://www.theonion.com/dad-clarifies-this-no...
# Name: article_link, Length: 28619, dtype: object

# %%
from urllib.parse import urlparse

# %%
df['article_domain'] = df['article_link'].apply(lambda x: urlparse(x).netloc.split('.')[-2])

# %%
df.head()
# Out:
#    is_sarcastic                                           headline  \
# 0             1  thirtysomething scientists unveil doomsday clo...
# 1             0  dem rep. totally nails why congress is falling...
# 2             0  eat your veggies: 9 deliciously different recipes
# 3             1  inclement weather prevents liar from getting t...
# 4             1  mother comes pretty close to using word 'strea...
#
#                                         article_link  article_domain
# 0  https://www.theonion.com/thirtysomething-scien...        theonion
# 1  https://www.huffingtonpost.com/entry/donna-edw...  huffingtonpost
# 2  https://www.huffingtonpost.com/entry/eat-your-...  huffingtonpost
# 3  https://local.theonion.com/inclement-weather-p...        theonion
# 4  https://www.theonion.com/mother-comes-pretty-c...        theonion

# %%
df.article_domain.value_counts()
# Out:
# huffingtonpost    14985
# theonion          13634
# Name: article_domain, dtype: int64

# %%
df['word_count'] = df['headline'].apply(lambda x: len(x.split()))

# %%
df.head()
# Out:
#    is_sarcastic                                           headline  \
# 0             1  thirtysomething scientists unveil doomsday clo...
# 1             0  dem rep. totally nails why congress is falling...
# 2             0  eat your veggies: 9 deliciously different recipes
# 3             1  inclement weather prevents liar from getting t...
# 4             1  mother comes pretty close to using word 'strea...
#
#                                         article_link  article_domain  \
# 0  https://www.theonion.com/thirtysomething-scien...        theonion
# 1  https://www.huffingtonpost.com/entry/donna-edw...  huffingtonpost
# 2  https://www.huffingtonpost.com/entry/eat-your-...  huffingtonpost
# 3  https://local.theonion.com/inclement-weather-p...        theonion
# 4  https://www.theonion.com/mother-comes-pretty-c...        theonion
#
#    word_count
# 0           8
# 1          13
# 2           7
# 3           8
# 4           9

# %%
df.word_count.describe()
# Out:
# count    28619.000000
# mean        10.049967
# std          3.388307
# min          2.000000
# 25%          8.000000
# 50%         10.000000
# 75%         12.000000
# max        151.000000
# Name: word_count, dtype: float64

# %%
sns.displot(df, x="word_count")
